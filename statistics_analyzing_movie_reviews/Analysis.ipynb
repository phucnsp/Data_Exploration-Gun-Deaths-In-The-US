# %% [markdown]
# # Explore dataset

# %%
import pandas as pd

movies = pd.read_csv('fandango_score_comparison.csv')
movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(movies['Metacritic_norm_round'], range = [0,5], bins = 10)
plt.show()
plt.hist(movies['Fandango_Stars'], range = [0,5], bins = 10)
plt.show()

# %% [markdown]
# - Metacritic film rate spread on whole range, from 0.5 to 4.5, while only above 3.00 seen with Fandango's.
# - Metacritic tends to centers at 3.0, 3.5 while Fandango seem to center at 4.0, 4.5.

# %% [markdown]
# # Mean, Median, Std

# %%
import numpy as np

mean_meta = movies['Metacritic_norm_round'].mean()
mean_fanda = movies['Fandango_Stars'].mean()
median_meta = np.median(movies['Metacritic_norm_round'])
median_fanda = np.median(movies['Fandango_Stars'])
std_meta = np.std(movies['Metacritic_norm_round'])
std_fanda = np.std(movies['Fandango_Stars'])

print('mean_meta', mean_meta)
print('mean_fanda', mean_fanda)
print('median_meta', median_meta)
print('median_fanda', median_fanda)
print('std_meta', std_meta)
print('std_fanda', std_fanda)
# Out:
# mean_meta 2.9726027397260273
# mean_fanda 4.089041095890411
# median_meta 3.0
# median_fanda 4.0
# std_meta 0.9875610297038636
# std_fanda 0.5385321612699531

# %% [markdown]
# # Fandango vs Metacritic Methodology

# %% [markdown]
# Fandango appears to inflate ratings and isn't transparent about how it calculates and aggregates ratings. Metacritic publishes each individual critic rating, and is transparent about how they aggregate them to get a final rating.

# %% [markdown]
# # Fandango vs Metacritic number differences¶

# %% [markdown]
# The median metacritic score appears higher than the mean metacritic score because a few very low reviews "drag down" the median. The median fandango score is lower than the mean fandango score because a few very high ratings "drag up" the mean.
#
# Fandango ratings appear clustered between 3 and 5, and have a much narrower random than Metacritic reviews, which go from 0 to 5.
#
# Fandango ratings in general appear to be higher than metacritic ratings.
#
# These may be due to movie studio influence on Fandango ratings, and the fact that Fandango calculates its ratings in a hidden way.

# %%
columns = ['Metacritic_norm_round','Fandango_Stars'] 
movies[columns].isnull().values.any()
# Out:
# False

# %%
ax = plt.scatter(x = movies['Metacritic_norm_round'], y = movies['Fandango_Stars'])

# %%
movies['fm_diff'] = movies['Metacritic_norm_round'] - movies['Fandango_Stars']
movies['fm_diff'] = movies['fm_diff'].abs()
movies.sort_values('fm_diff', ascending = False).head(5)
# Out:
#                         FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 3     Do You Believe? (2015)              18                   84          22
# 85         Little Boy (2015)              20                   81          30
# 47              Annie (2014)              27                   61          33
# 19             Pixels (2015)              17                   54          27
# 134  The Longest Ride (2015)              31                   73          33
#
#      Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 3                4.7   5.4             5.0                   4.5     0.90
# 85               5.9   7.4             4.5                   4.3     1.00
# 47               4.8   5.2             4.5                   4.2     1.35
# 19               5.3   5.6             4.5                   4.1     0.85
# 134              4.8   7.2             4.5                   4.5     1.55
#
# ...

# %%
from scipy.stats.stats import pearsonr
r, p_value = pearsonr(movies['Metacritic_norm_round'], movies['Fandango_Stars'])
r
# Out:
# 0.17844919073895918

# %% [markdown]
# - Correlation value r is very low, there is no correlation between Meta and Fanda review score.

# %%
from scipy.stats import linregress
slope, intercept, r_value, p_value, stderr_slope = linregress(movies['Metacritic_norm_round'], movies['Fandango_Stars'])

predicted_3 = slope * 3.0 + intercept
predicted_3
# Out:
# 4.0917071528212041

# %%
pred_1 = 1 * slope + intercept
pred_5 = 5 * slope + intercept
plt.scatter(movies["Metacritic_norm_round"], movies["Fandango_Stars"])
plt.plot([1,5],[pred_1,pred_5])
plt.xlim(1,5)
plt.show()
